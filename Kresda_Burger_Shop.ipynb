# %% [markdown]
# # Self-Assessment: Burger Shop
#
# You have been tasked with building a user interface for a new restaurant named Burger Shop that allows customers to place custom orders for hamburgers.
#
# ## Instructions
#
# Update the code below to create a working program.
#
# The provided code includes a framework for the program, including a series of classes that represent each item a customer might purchase, such as burgers, sides (e.g., fries, onion rings, or a garden salad), drinks, and combo platters that include multiple items. Note that each of these classes inherits from a FoodItem class that should define the properties that are common to all items on the menu. The framework also includes functions that you will define to work with the classes and create the customer's order.
#
# Start by asking the customer for their name, which will be used to identify the order. The program should then perform the following steps:
#
# > - Ask the customer if they want a burger, a side, a drink, or a combo.
# > - A combo must include a burger, a side, and a drink.
# > - Prompt them for details about their selection, such as condiments for a burger, what kind and size of drink, and so on.
# > - Create the item based on their selections.
# > - Add the item to the Order class.
# > -  Repeat these steps until the customer doesn't want to order anything else.
# > - Display the order details including the price.
# > - Thank the customer for their business.
# > - A complete order output should include at least one of the items on the menu, the price for each item ordered, and the total price based on all items in the order.
#
# Also include an option that allows the customer to cancel their order at any point in the ordering process. The output should thank the user for their business but not display anything ordered.
#
# ## Requirements
# It is entirely up to you to decide details such as prices, what condiments and sides are available, and so on. However, the program must meet the following requirements:
#
# > - Include your name and a current date in a comment on the first line of code.
# > - Use the classes provided in the Starter Code below as a starting point. Create additional classes as necessary to streamline the code.
# > - All text displayed to the user must be meaningful and use correct spelling and grammar.
# > - The customer must be able to order anything on the menu. (It might be useful to display menu options to the user, so they know what they can select.)
# > - The customer must be able to cancel the order at any time in the ordering process.
# > - The program must handle errors gracefully. For example, if the user enters an item that is not on the menu, the program should inform the user of the problem and prompt them to order something else instead.

# %%
# implement the classes listed below 
class FoodItem:
    pass
class Burger(FoodItem):
    pass
class Drink(FoodItem):
    pass
class Side(FoodItem):
    pass
class Combo(FoodItem):
    pass
class Order:
    pass
 
def user_input_burger():
    b = Burger()
    #ask user for input and store it in burger object 
    return b
 
def user_input_drink():
    d = Drink()
    #ask user for input and store it in drink object 
    return d
 
def user_input_side():
    s = Side()
    #ask user for input and store it in side object 
    return s
 
def user_input_combo():
    c = Combo()
    #ask user for input and store it in combo object 
    #a combo must include one burger, one side, and one drink
    return c
 
def take_order(self):
    #ask user for name for the order 
    #repeat taking order until client is done 
    #display order details
    #display a thank you message
    print("Welcome to Burger Shop")

 
take_order()
# Out:
# Welcome to Burger Shop

# %%
class FoodItem:
    def __init__(self, name):
        self.name = name # Name of food item
    def info(self):
        return self.name 
    def buildmenu(name):
        menu = []
        for i in range(len(name)):
            menu.append(FoodItem(name[i]))
        return menu
    pass
class Burger(FoodItem):
    def __init__(self, name, price):
        self.name = name # burger name
        self.price = price # burger price
    
    pass
class Drink(FoodItem):
    def __init__(self, size, price):
        # self.name = name # Drink name
        self.price = price # Drink price
        self.size = size # Drink size
    def drink_price(self):
        return self.price
    pass
class Side(FoodItem):
    def __init__(self, name, price):
        self.name = name # side name
        self.price = price # side price
    pass
    def side_price(self):
        return self.price
class Combo(FoodItem):
    def __init__(self,side, name, size, price):
        self.name = name # combo name
        self.price = price # combo price
        self.size = size # combo size
    def combo(name, side, size, drink, price):
        return name, size, price
    pass
class Order:
    pass

food_item1 = FoodItem('Burger')
food_item2 = FoodItem('Fries')
food_item3 = FoodItem('Onion Rings')
food_item4 = FoodItem('Garden Salad')
food_item5 = FoodItem('Coke')
food_item6 = FoodItem('Diet Coke')

burger1 = Burger('Burger', 5)

drink1 = Drink('Small', 3)
drink2 = Drink('Medium', 4)
drink3 = Drink('Large', 5)

side1 = Side('Fries', 2)
side2 = Side('Onion Rings', 2)
side3 = Side('Garden Salad', 2)

combo1 = Combo('Burger', 'Fries', 'Medium', 'Coke')

food_items = [food_item1, food_item2, food_item3, food_item4, food_item5, food_item6]
drink_sizes = [drink1, drink2, drink3]
side_items =  [side1, side2, side3]

index = 0
for food_item in food_items:
    print(str(index)+'. ' + food_item.info())
    index+=1

# index = 0 
# for drink_item in drink_sizes:
#     print(drink_item.drink_price())
#     index += 1

# index = 0 
# for side_item in side_items:
#     print(side_item.side_price())
#     index += 1

# order = int(input("Enter menu item number: "))
# selected_menu = food_items[order]
# print('Selected item: ' + selected_menu.name)
# Out:
# 0. Burger
# 1. Fries
# 2. Onion Rings
# 3. Garden Salad
# 4. Coke
# 5. Diet Coke

# %%
class FoodItem:
    def __init__(self, name):
        self.name = name # Name of food item
    def info(self):
        return self.name 
    def buildmenu(name):
        menu = []
        for i in range(len(name)):
            menu.append(FoodItem(name[i]))
        return menu
    pass
class Burger(FoodItem):
    def __init__(self, name, burger_price):
        self.burger_price = b_price # burger price
    def burger_price(b_price):
        return b_price
    pass
class Drink(FoodItem):
    def __init__(self, name, size, price):
        self.name = name # Drink name
        self.price = price # Drink price
        self.size = size # Drink size
    pass
class Side(FoodItem):
    def __init__(self, name, price):
        self.name = name # side name
        self.price = price # side price
    pass
class Combo(FoodItem):
    def __init__(self, name, size, price):
        self.name = name # combo name
        self.price = price # combo price
        self.size = size # combo size
    def combo(name, size, price):
        return name, size, price
    pass
class Order:
    pass

# food_item1 = FoodItem('Burger')
# food_item2 = FoodItem('Fries')
# food_item3 = FoodItem('Onion Rings')
# food_item4 = FoodItem('Garden Salad')
# food_item5 = FoodItem('Coke')
# food_item6 = FoodItem('Diet Coke')

# burger1 = Burger('Burger', 5)

# food_items = [food_item1, food_item2, food_item3, food_item4, food_item5, food_item6]

# index = 0
# for food_item in food_items:
#     print(str(index)+'. ' + food_item.info())
#     index+=1

# order = int(input("Enter menu item number: "))
# selected_menu = food_items[order]
# print('Selected item: ' + selected_menu.name)

# %%
class FoodItem:
    def __init__(self, name):
        self.name = name # Name of food item
    def info(self):
        return self.name 
    def buildmenu(name):
        menu = []
        for i in range(len(name)):
            menu.append(FoodItem(name[i]))
        return menu
    pass
class Burger(FoodItem):
    def __init__(self, name, price):
        self.name = name # burger name
        self.price = price # burger price
    
    pass
class Drink(FoodItem):
    def __init__(self, drink_name):
        self.drink_name = drink_name # Drink name
    pass
class DrinkSize(Drink):
    def __init__(self, drink_name, drink_price ,size):
        self.drink_price = drink_price # Drink price
    def drink_price(self):
        return self.price
    
class Side(FoodItem):
    def __init__(self, name, price):
        self.name = name # side name
        self.price = price # side price
    pass
    def side_price(self):
        return self.price
class Combo(FoodItem):
    def __init__(self,side, name, size, price):
        self.name = name # combo name
        self.price = price # combo price
        self.size = size # combo size
    def combo(name, side, size, drink, price):
        return name, size, price
    pass
class Order:
    pass

# %%
class FoodItem:
    def __init__(self, name):
        self.name = name # Name of food item
    def info(self):
        return self.name
    def display(self):
        print(self.name)
    pass

class Burger(FoodItem):
    def __init__(self, name, bur_price):
        FoodItem.__init__(self,name)
        self.burger_price = bur_price
    def price(self):
        return self.burger_price
    pass

class Drink(FoodItem):
    def __init__(self, drink_name,name  ,drink_price):
        FoodItem.__init__(self,name)
        self.size_price = drink_price
    def price(self):
        print(self.drink_name)
        print(self.name)
        return self.size_price
    pass

class Side(FoodItem):
    pass
class Combo(FoodItem):
    pass
class Order:
    pass

food1 = FoodItem("Burger")
food1.display()

burger1 = Burger("Chicken Burger", 5)
print(burger1.price())
print(burger1.display())

# drink1 = Drink( "coke", "small", 2)
# small_price = drink1.price()
# print(small_price)
# Out:
# Burger
# 5
# Chicken Burger
# None

# %%
class Person:
    def __init__(self,fname,lname): 
        self.first_name = fname
        self.last_name = lname

 
class Employee(Person):
    employee_id=None
    def __init__(self,emp_id,fname,lname):
    
        Person.__init__(self,fname,lname) 
        self.employee_id =emp_id
    def display(self):
        print("Employee ID: " + self.employee_id)
        print("Employee First Name: " + self.first_name)
        print("Employee Last Name: " + self.last_name)
 
e = Employee("E15454513","Haythem","Balti")
 
 
e.display()
# Out:
# Employee ID: E15454513
# Employee First Name: Haythem
# Employee Last Name: Balti

# %%
class Parent():
    def __init__(self):
        self.myvar = 'coke'

class Child(Parent):
    def __init__(self):
        Parent.__init__(self)

        # here you can access myvar like below.
        print (self.myvar)

child = Child()
print (child.myvar)
# Out:
# coke
# coke

# %%
class FoodItem:
    def __init__(self, name, price):
        self.name = name 
        self.price = price

    def info(self):
        return self.name + ": "+ str(self.price)

    pass

class Burger(FoodItem):
    pass
    # def __init__(self, type):
    #     FoodItem.__init__("Chicken Burger", 5)
    #     self.type = type
    # def display(self):
    #     print(type)
class Drink(FoodItem):
    def 
    pass
class Side(FoodItem):
    pass
class Combo(FoodItem):
    pass
class Order:
    pass
food1 = Burger('Chicken Burger', 5)
print(food1.info())
drink1 = Drink('Coke', 2)
print(drink1.info())
side1 = Side('Fries', 2)
print(side1.info())
# Out:
# Chicken Burger: 5
# Coke: 2
# Fries: 2

# %%
def take_order():
    print("Welcome to the Burger Shop!")
    name = input("What is your name? ")
    print('Hello', name)
    combo1 = ["Chicken Burger", "Fries", "Coke", 'Ketchup', 'Small']
    combo2 = ["Beef Burger", "Fries", 'Coke', 'Ketchup', 'Large']
    combo3 = ["Chicken Burger", "Onion Rings", "Diet Coke",'Bbq', 'Medium' ]
    combo4 = ["Beef Burger", "Garden Salad", 'Diet Coke','Bbq', 'Large' ]
    combo_lst = [combo1, combo2, combo3, combo4]

    user_combo = input ('Would you like a combo, yes or no?')
    if user_combo == 'yes':
        print("Choose from the following Combos:")
        for count, value in enumerate( combo_lst):
            print ( str(count) + ". " + str(value) )
        user_combo_input = input ('Which combo would you like? Enter a number: ')
        chosen_combo = combo_lst[int(user_combo_input)]
        print("Your chosen combo is: ", chosen_combo)
    elif user_combo == 'no':
        chosen_combo =[]
        burger = input('Do you want a Chicken or Beef Burger?')
        if burger == "chicken" or burger == "Chicken Burger":
            chosen_combo.append("Chicken Burger")
        if burger == "beef" or burger == "Beef burger":
            chosen_combo.append("Beef Burger")

        side = input('Do you want Fries, Onion Rings or Garden Salad')
        if side == 'fries' or side == 'Fries':
            chosen_combo.append("Fries")
        elif side == 'onion rings' or side == 'Onion Rings':
            chosen_combo.append('Onion Rings')
        elif side == 'garden salad' or side == 'Garden Salad':
            chosen_combo.append('Garden Salad')

        drink = input('Do you want coke or diet coke?')
        if drink == 'coke' or drink == 'Coke':
            chosen_combo.append('Coke')
        elif drink == 'diet coke':
            chosen_combo.append('Diet Coke')
        print("Your chosen Combo is: ", chosen_combo)

        condiment = input ("Would you like ketchup or bbq?")
        if condiment == "ketchup":
            chosen_combo.append(condiment)
        if condiment == 'Bbq':
            chosen_combo.append(condiment)

        size = input ("Would you like Small, Medium or Large Drink?")
        if size == 'small' or size == 'Small':
            chosen_combo.append('Small')
        elif size == 'medium' or size == 'Medium':
            chosen_combo.append('Medium')
        elif size == 'large' or size == 'Large':
            chosen_combo.append('Large')
        print("Your Chosen Combo is: ", chosen_combo)
    return chosen_combo

# %%
take_order()
burger = chosen_combo[0]
side = chosen_combo[1]
drink = chosen_combo[2]
condiment = chosen_combo[3]
size = chosen_combo[4]

for i in chosen_combo:
    print(i)
# Out:
# Welcome to the Burger Shop!
# Hello kresda
# Choose from the following Combos:
# 0. ['Chicken Burger', 'Fries', 'Coke', 'Ketchup', 'Small']
# 1. ['Beef Burger', 'Fries', 'Coke', 'Ketchup', 'Large']
# 2. ['Chicken Burger', 'Onion Rings', 'Diet Coke', 'Bbq', 'Medium']
# 3. ['Beef Burger', 'Garden Salad', 'Diet Coke', 'Bbq', 'Large']
# Your chosen combo is:  ['Beef Burger', 'Garden Salad', 'Diet Coke', 'Bbq', 'Large']
# Beef Burger
# Garden Salad
# Diet Coke
# Bbq
# Large

# %%
class FoodItem:
    def __init__(self, name, price):
        self.name = name 
        self.price = price
    def info(self):
        return self.name
    def total(self):
        return self.price
    pass 
class Burger(FoodItem):
    def __init__(self,name,price):
        super().__init__( name, price)
    pass 
class Drink(FoodItem):
    def __init__(self,name,price):
        super().__init__( name, price)
    def drink_size(self, size):
        self.size = size
        return self.size
    pass 
class Side(FoodItem):
    pass 
class Combo(FoodItem):
    pass 
class Condiment(FoodItem):
    pass
class Order:
    pass 
 
burger1 = Burger('Chicken Burger', 5)
burger2 = Burger('Beef Burger', 5)
side1 = Side('Fries', 3)
side2 = Side('Onion Rings', 3)
side3 = Side('Garden Salad', 3)
drink1 = Drink('Coke', 2)
drink2 = Drink('Diet Coke', 2)
condiment1 = Condiment('Ketchup', 1)
condiment2 = Condiment('BBQ', 1)


drink1.name


# burger1 = Burger(burger,5)
# Out:
# 'Coke'

# %%
class FoodItem:
    def __init__(self, name):
        self.name = name 
        
    def info(self):
        return self.name
    
    pass 
class Burger(FoodItem):
    def __init__(self,name,price):
        super().__init__( name, price)
    pass 
class Drink(FoodItem):
    def __init__(self,name):
        super().__init__( name, )
   
class DrinkSize(FoodItem):
    def __init__(self,name):
        super().__init__( name)
    def drink_price(self):
        if self.name == 'Small':
            self.price = 2
        elif self.name == "Medium":
            self.price = 3
        elif self.name == "Large":
            self.price = 4
        return self.price
    pass 
    
class Side(FoodItem):
    def __init__(self,name):
        super().__init__( name)
    def side_price(self):
        if self.name == 'Fries':
            self.price = 3
        elif self.name == "Onion Rings":
            self.price = 3
        elif self.name == "Garden Salad":
            self.price = 3
        return self.price
    pass 

class Combo(FoodItem):
    pass 
class Condiment(FoodItem):
    def __init__(self,name):
        super().__init__( name)
    def condiment_price(self):
        if self.name == 'Ketchup':
            self.price = 1
        elif self.name == "Bbq":
            self.price = 1
        return self.price
    pass
class Order:
    pass 
 
# burger1 = Burger('Chicken Burger', 5)
# burger2 = Burger('Beef Burger', 5)
# side1 = Side('Fries', 3)
# side2 = Side('Onion Rings', 3)
# side3 = Side('Garden Salad', 3)
# drink1 = Drink('Coke')
# drink2 = Drink('Diet Coke') 
drink_size1 = DrinkSize("Small")
drink_size2 = DrinkSize("Medium")
drink_size3 = DrinkSize("Large")

condiment1 = Condiment('Ketchup')
condiment2 = Condiment('Bbq')


size_price = drink_size3.drink_price()
print(size_price)

condiment_price = condiment1.condiment_price()
print(condiment_price)
# Out:
# 4
# 1
