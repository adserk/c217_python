# %% [markdown]
# # Self-Assessment: Burger Shop
#
# You have been tasked with building a user interface for a new restaurant named Burger Shop that allows customers to place custom orders for hamburgers.
#
# ## Instructions
#
# Update the code below to create a working program.
#
# The provided code includes a framework for the program, including a series of classes that represent each item a customer might purchase, such as burgers, sides (e.g., fries, onion rings, or a garden salad), drinks, and combo platters that include multiple items. Note that each of these classes inherits from a FoodItem class that should define the properties that are common to all items on the menu. The framework also includes functions that you will define to work with the classes and create the customer's order.
#
# Start by asking the customer for their name, which will be used to identify the order. The program should then perform the following steps:
#
# > - Ask the customer if they want a burger, a side, a drink, or a combo.
# > - A combo must include a burger, a side, and a drink.
# > - Prompt them for details about their selection, such as condiments for a burger, what kind and size of drink, and so on.
# > - Create the item based on their selections.
# > - Add the item to the Order class.
# > -  Repeat these steps until the customer doesn't want to order anything else.
# > - Display the order details including the price.
# > - Thank the customer for their business.
# > - A complete order output should include at least one of the items on the menu, the price for each item ordered, and the total price based on all items in the order.
#
# Also include an option that allows the customer to cancel their order at any point in the ordering process. The output should thank the user for their business but not display anything ordered.
#
# ## Requirements
# It is entirely up to you to decide details such as prices, what condiments and sides are available, and so on. However, the program must meet the following requirements:
#
# > - Include your name and a current date in a comment on the first line of code.
# > - Use the classes provided in the Starter Code below as a starting point. Create additional classes as necessary to streamline the code.
# > - All text displayed to the user must be meaningful and use correct spelling and grammar.
# > - The customer must be able to order anything on the menu. (It might be useful to display menu options to the user, so they know what they can select.)
# > - The customer must be able to cancel the order at any time in the ordering process.
# > - The program must handle errors gracefully. For example, if the user enters an item that is not on the menu, the program should inform the user of the problem and prompt them to order something else instead.

# %%
class FoodItem:
    def __init__(self, name):
        self.name = name 
        
    def info(self):
        return self.name
    
    pass 
class Burger(FoodItem):
    def __init__(self,name):
        super().__init__( name)
    def burger_price(self):
        if self.name == 'Chicken Burger':
            self.price = 5
        elif self.name == "Beef Burger":
            self.price = 5
        return self.price
    pass 
class Drink(FoodItem):
    def __init__(self,name):
        super().__init__( name, )
   
class DrinkSize(FoodItem):
    def __init__(self,name):
        super().__init__( name)
    def drink_price(self):
        if self.name == 'Small':
            self.price = 2
        elif self.name == "Medium":
            self.price = 3
        elif self.name == "Large":
            self.price = 4
        return self.price
    pass 
    
class Side(FoodItem):
    def __init__(self,name):
        super().__init__( name)
    def side_price(self):
        if self.name == 'Fries':
            self.price = 3
        elif self.name == "Onion Rings":
            self.price = 3
        elif self.name == "Garden Salad":
            self.price = 3
        return self.price
    pass 

class Combo(FoodItem):
    pass 
class Condiment(FoodItem):
    def __init__(self,name):
        super().__init__( name)
    def condiment_price(self):
        if self.name == 'Ketchup':
            self.price = 1
        elif self.name == "Bbq":
            self.price = 1
        return self.price
    pass
class Order:
    pass

# %%
# Take Order function
def take_order(order_num,name):
    if order_num == 1:            
        print('Hi ' + str(name) + '. Here is our Menu:')
        print ('-------------------')
        food_menu()
        drinks_menu()
        sides_menu()
        combo_menu()
    elif order_num > 1:
        print("What else would you like to order " + str(name) + "?")
    
    combo1 = ["Chicken Burger", "Fries", "Coke", 'Ketchup', 'Small']
    combo2 = ["Beef Burger", "Fries", 'Coke', 'Ketchup', 'Large']
    combo3 = ["Chicken Burger", "Onion Rings", "Diet Coke",'Bbq', 'Medium' ]
    combo4 = ["Beef Burger", "Garden Salad", 'Diet Coke','Bbq', 'Large' ]
    combo_lst = [combo1, combo2, combo3, combo4]

    # Make sure the user enters 'yes' or 'no'
    user_combo = input ('Would you like a combo, yes or no?')
    while (user_combo != 'yes') and (user_combo != 'no'):
        print ('Enter yes or no')
        user_combo = input ('Would you like a combo, yes or no?')
        
    # Convert input to lower case to prevent syntax errors
    user_combo = user_combo.lower()
    if user_combo == 'yes':
        # print("Choose from the following Combos:")
        # for count, value in enumerate( combo_lst):
        #     print ( str(count) + ". " + str(value) )
        combo_num = (len(combo_lst) - 1)
        user_combo_input = input ('Which combo would you like? Enter a number between 0 and ' + str(combo_num))
        
        while int(user_combo_input) > combo_num:
            print('Error, please enter a number between 0 and ' + str(combo_num))
            user_combo_input = input('Which combo would you like? Enter a number between 0 and ' + str(combo_num))
        chosen_combo = combo_lst[int(user_combo_input)]
        print ('-------------------')
        print("Your chosen combo is: ", chosen_combo)

    elif user_combo == 'no':
        chosen_combo =[]
        burger = input('Do you want a Chicken or Beef Burger?')
        burger = burger.lower()
        if burger == "chicken" or burger == "chicken burger":
            chosen_combo.append("Chicken Burger")
        if burger == "beef" or burger == "beef burger":
            chosen_combo.append("Beef Burger")

        
        side = input('Do you want Fries, Onion Rings or Garden Salad')
        # Convert input to lower case to prevent syntax errors
        side = side.lower()
        if side == 'fries' :
            chosen_combo.append("Fries")
        elif side == 'onion rings' :
            chosen_combo.append('Onion Rings')
        elif side == 'garden salad' :
            chosen_combo.append('Garden Salad')

        drink = input('Do you want coke or diet coke?')
        # Convert input to lower case to prevent syntax errors
        drink = drink.lower()
        if drink == 'coke' :
            chosen_combo.append('Coke')
        elif drink == 'diet coke' or drink == 'diet':
            chosen_combo.append('Diet Coke')

        condiment = input ("Would you like Ketchup or Bbq?")
        # Convert input to lower case to prevent syntax errors
        condiment = condiment.lower()
        if condiment == "ketchup" :
            chosen_combo.append("Ketchup")
        elif condiment == 'bbq' :
            chosen_combo.append("Bbq")

        size = input ("Would you like Small, Medium or Large Drink?")
        # Convert input to lower case to prevent syntax errors
        size = size.lower()
        if size == 'small' or size == 'small drink':
            chosen_combo.append('Small')
        elif size == 'medium' or size == 'medium drink':
            chosen_combo.append('Medium')
        elif size == 'large drink' or size == "large" :
            chosen_combo.append('Large')
        print ('-------------------')
        print("Your Chosen Combo is: ", chosen_combo)

    return chosen_combo

# Display Menu Food menu function
def food_menu():
    food_items = ['Chicken Burger', 'Beef Burger', 'Fries', 'Onion Rings', 'Garden Salad']
    food_prices = [5,5,3,3,3]
    j = 0
    print("Food Menu")
    print ('-------------------')
    for i in food_items:
        print(i + ' : ' + "£" + str(food_prices[j]))
        j += 1

# Display Drinks Menu function
def drinks_menu():
    drink_items = ['Coke', 'Diet Coke']
    drink_sizes = ['Small', 'Medium', 'Large']
    drink_prices = [2, 3, 4]
    print('\n')
    print("Drinks Menu")
    j = 0
    print ('-------------------')
    for i in drink_items:
        print(i)
    # print('\n')
    print('Choose from the following drink sizes:')
    print ('-------------------')
    for i in drink_sizes:
        print(i + ' : ' + "£" + str(drink_prices[j]))
        j += 1

# Sides Menu function
def sides_menu():
    side_items = ['Fries','Onion Rings', 'Garden Salad']
    side_prices = [3, 3, 3]
    j =0
    print('\n')
    print("Sides Menu")
    print ('-------------------')
    for i in side_items:
        print(i + ' : ' + "£" + str(side_prices[j]))
        j += 1

# Combo Menu function
def combo_menu():
    combo1 = ["Chicken Burger", "Fries", "Coke", 'Ketchup', 'Small']
    combo2 = ["Beef Burger", "Fries", 'Coke', 'Ketchup', 'Large']
    combo3 = ["Chicken Burger", "Onion Rings", "Diet Coke",'Bbq', 'Medium' ]
    combo4 = ["Beef Burger", "Garden Salad", 'Diet Coke','Bbq', 'Large' ]
    combo_lst = [combo1, combo2, combo3, combo4]
    combo_prices = [11,13,12,13]

    j =0
    print('\n')
    print("Combos Menu")
    print ('-------------------')
    for i in combo_lst:
        print(str(j)+ ". " + str(i) + ' : ' + "£" +  str(combo_prices[j]))
        j += 1

# %%
print("Welcome to the Burger Shop!")
user_input = input("Would you like to place an order? yes or no: ")
user_input = user_input.lower()
order_num = 1
previous_total = 0
if user_input == "no":
    print("No problem. See you next time.")
while (user_input != 'no'):
    if order_num == 1:
        name = input("What is your name?")
    chosen_combo = take_order(order_num,name)
    burger = chosen_combo[0]
    side = chosen_combo[1]
    drink = chosen_combo[2]
    condiment = chosen_combo[3]
    size = chosen_combo[4]

    burger_chosen = Burger(burger)
    burger_price = burger_chosen.burger_price()
    print("Price of Chosen Burger " + "(" + str(burger) + ") = " + '£' + str(burger_price))

    side_chosen = Side(side)
    side_price = side_chosen.side_price()
    print("Price of Chosen Side " + "(" + str(side) + ") = " + '£' + str(side_price))

    drink_size_chosen = DrinkSize(size)
    drink_price = drink_size_chosen.drink_price()
    print("Price of Chosen Drink " + "(" + str(drink) + ") = " + '£' + str(drink_price))

    condiment_chosen = Condiment(condiment)
    condiment_price = condiment_chosen.condiment_price()
    print("Price of Chosen Condiment " + "(" + str(condiment) + ") = " + '£' + str(condiment_price))
    print ('-------------------')
  
    total=burger_price+side_price+drink_price+condiment_price
    previous_total=total+previous_total
    print("Your order number is " + str(order_num) + ".")
    
    print ('-------------------')

    user_input = input("Order again? yes or no: ")
    user_input = user_input.lower()
    if user_input == 'no':
        if order_num == 1:
            print("You have " + str(order_num) + ' order.')
            print('Your Total Bill is '+ "£" + str(previous_total) + ".")
            print("Thank you very much for your order " + str(name) + ". Enjoy your food!")

        elif order_num > 1:
            print("You have " + str(order_num) + ' orders.')
            print('Your Total Bill is '+ "£" + str(previous_total) + ".")
            print("Thank you very much for your orders " + str(name) + ". Enjoy your food!")
    order_num += 1
# Out:
# Welcome to the Burger Shop!
# Hi kresda. Here is our Menu:
# -------------------
# Food Menu
# -------------------
# Chicken Burger : £5
# Beef Burger : £5
# Fries : £3
# Onion Rings : £3
# Garden Salad : £3
#
#
# Drinks Menu
# -------------------
# Coke
# Diet Coke
# Choose from the following drink sizes:
# -------------------
# Small : £2
# Medium : £3
# Large : £4
#
#
# Sides Menu
# -------------------
# Fries : £3
# Onion Rings : £3
# Garden Salad : £3
#
#
# Combos Menu
# -------------------
# 0. ['Chicken Burger', 'Fries', 'Coke', 'Ketchup', 'Small'] : £11
# 1. ['Beef Burger', 'Fries', 'Coke', 'Ketchup', 'Large'] : £13
# 2. ['Chicken Burger', 'Onion Rings', 'Diet Coke', 'Bbq', 'Medium'] : £12
# 3. ['Beef Burger', 'Garden Salad', 'Diet Coke', 'Bbq', 'Large'] : £13
# Enter yes or no
# -------------------
# Your Chosen Combo is:  ['Chicken Burger', 'Fries', 'Diet Coke', 'Bbq', 'Medium']
# Price of Chosen Burger (Chicken Burger) = £5
# Price of Chosen Side (Fries) = £3
# ...
