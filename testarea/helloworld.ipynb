# %%
print ("hello world")
# Out:
# hello world

# %%
import array as arr
import numpy as np

array = np.array([3,6,9,12])
for i in array:
    print(i)
# Out:
# 3
# 6
# 9
# 12

# %%
import pandas_datareader as data
import pandas as pd

# %%
tickers = ['GOOG','AMZN','MSFT','AAPL', 'FB']
data_source = 'yahoo'
start_date = '2016-01-01'
end_date = '2022-04-22'
Google = data.DataReader('GOOG', data_source, start_date, end_date)
Amazon = data.DataReader('AMZN', data_source, start_date, end_date)
Microsoft = data.DataReader('MSFT', data_source, start_date, end_date)
Apple = data.DataReader('AAPL', data_source, start_date, end_date)
Facebook = data.DataReader('FB', data_source, start_date, end_date)

# %%
df = pd.concat([Google, Amazon, Microsoft, Apple, Facebook], axis=1, keys=tickers)
df.head(3)
# Out:
#                   GOOG                                               \
#                   High         Low        Open       Close   Volume
# Date
# 2016-01-04  744.059998  731.257996  743.000000  741.840027  3272800
# 2016-01-05  752.000000  738.640015  746.450012  742.580017  1950700
# 2016-01-06  747.179993  728.919983  730.000000  743.619995  1947000
#
#                               AMZN                                      ...  \
#              Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2016-01-04  741.840027  657.719971  627.510010  656.289978  636.989990  ...
# 2016-01-05  742.580017  646.909973  627.650024  646.859985  633.789978  ...
# 2016-01-06  743.619995  639.789978  620.309998  622.000000  632.650024  ...
#
#                  AAPL                                             FB  \
#                  Open      Close       Volume  Adj Close        High
# Date
# 2016-01-04  25.652500  26.337500  270597600.0  24.220573  102.239998
# 2016-01-05  26.437500  25.677500  223164000.0  23.613626  103.709999
# 2016-01-06  25.139999  25.174999  273829600.0  23.151512  103.769997
#
#
#                    Low        Open       Close    Volume   Adj Close
# Date
# 2016-01-04   99.750000  101.949997  102.220001  37912400  102.220001
# 2016-01-05  101.669998  102.889999  102.730003  23258200  102.730003
# 2016-01-06  100.900002  101.129997  102.970001  25096200  102.970001
#
# [3 rows x 30 columns]

# %%
df.columns.names = ['Stock Ticker', 'Stock Info']
df.head()
# Out:
# Stock Ticker        GOOG                                               \
# Stock Info          High         Low        Open       Close   Volume
# Date
# 2016-01-04    744.059998  731.257996  743.000000  741.840027  3272800
# 2016-01-05    752.000000  738.640015  746.450012  742.580017  1950700
# 2016-01-06    747.179993  728.919983  730.000000  743.619995  1947000
# 2016-01-07    738.500000  719.059998  730.309998  726.390015  2963700
# 2016-01-08    733.229980  713.000000  731.450012  714.469971  2450900
#
# Stock Ticker                    AMZN                                      ...  \
# Stock Info     Adj Close        High         Low        Open       Close  ...
# Date                                                                      ...
# 2016-01-04    741.840027  657.719971  627.510010  656.289978  636.989990  ...
# 2016-01-05    742.580017  646.909973  627.650024  646.859985  633.789978  ...
# 2016-01-06    743.619995  639.789978  620.309998  622.000000  632.650024  ...
# 2016-01-07    726.390015  630.000000  605.210022  621.799988  607.940002  ...
# 2016-01-08    714.469971  624.140015  606.000000  619.659973  607.049988  ...
#
# Stock Ticker       AAPL                                             FB  \
# Stock Info         Open      Close       Volume  Adj Close        High
# Date
# 2016-01-04    25.652500  26.337500  270597600.0  24.220573  102.239998
# 2016-01-05    26.437500  25.677500  223164000.0  23.613626  103.709999
# 2016-01-06    25.139999  25.174999  273829600.0  23.151512  103.769997
# 2016-01-07    24.670000  24.112499  324377600.0  22.174414  101.430000
# 2016-01-08    24.637501  24.240000  283192000.0  22.291664  100.500000
#
# Stock Ticker
# Stock Info           Low        Open       Close    Volume   Adj Close
# Date
# 2016-01-04     99.750000  101.949997  102.220001  37912400  102.220001
# 2016-01-05    101.669998  102.889999  102.730003  23258200  102.730003
# 2016-01-06    100.900002  101.129997  102.970001  25096200  102.970001
# 2016-01-07     97.300003  100.500000   97.919998  45172900   97.919998
# 2016-01-08     97.029999   99.879997   97.330002  35402300   97.330002
#
# [5 rows x 30 columns]

# %%
df.xs(key='GOOG', axis=1, level='Stock Ticker')
# Out:
# Stock Info         High          Low         Open        Close   Volume  \
# Date
# 2016-01-04   744.059998   731.257996   743.000000   741.840027  3272800
# 2016-01-05   752.000000   738.640015   746.450012   742.580017  1950700
# 2016-01-06   747.179993   728.919983   730.000000   743.619995  1947000
# 2016-01-07   738.500000   719.059998   730.309998   726.390015  2963700
# 2016-01-08   733.229980   713.000000   731.450012   714.469971  2450900
# ...                 ...          ...          ...          ...      ...
# 2022-04-18  2574.239990  2531.569092  2548.199951  2559.219971   745900
# 2022-04-19  2618.074951  2549.030029  2561.540039  2610.620117  1136000
# 2022-04-20  2638.469971  2557.881104  2625.679932  2564.909912  1130500
# 2022-04-21  2606.149902  2493.000000  2587.000000  2498.750000  1507900
# 2022-04-22  2509.040039  2382.810059  2500.000000  2392.280029  2317600
#
# Stock Info    Adj Close
# Date
# 2016-01-04   741.840027
# 2016-01-05   742.580017
# 2016-01-06   743.619995
# 2016-01-07   726.390015
# 2016-01-08   714.469971
# ...                 ...
# 2022-04-18  2559.219971
# 2022-04-19  2610.620117
# 2022-04-20  2564.909912
# 2022-04-21  2498.750000
# 2022-04-22  2392.280029
#
# [1588 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
# %matplotlib inline

# %%
px.line(df.xs(key='AAPL', axis=1, level='Stock Ticker')['Close'])

# %%
px.line(df.xs(key='AAPL', axis=1, level='Stock Ticker')['Close'], range_x=['2020-01-01','2020-12-31'])

# %%
px.line(df.xs(key='Close', axis=1, level='Stock Info')[['GOOG', 'AMZN']])

# %%
df.xs(key='Close', axis=1, level='Stock Info').head()
c = df.xs(key='Close', axis=1, level='Stock Info')
c.head()
# Out:
# Stock Ticker        GOOG        AMZN       MSFT       AAPL          FB
# Date
# 2016-01-04    741.840027  636.989990  54.799999  26.337500  102.220001
# 2016-01-05    742.580017  633.789978  55.049999  25.677500  102.730003
# 2016-01-06    743.619995  632.650024  54.049999  25.174999  102.970001
# 2016-01-07    726.390015  607.940002  52.169998  24.112499   97.919998
# 2016-01-08    714.469971  607.049988  52.330002  24.240000   97.330002

# %%
plt.figure(figsize=(20,10))
fig = px.line(c)
fig.show()

# %%
plt.figure(figsize=(20,10))
fig = px.area(c, facet_col='Stock Ticker', facet_col_wrap=3)
fig.show()

# %%
fig = px.line(c, range_x=['2020-01-01','2020-12-31'])
fig.show()
